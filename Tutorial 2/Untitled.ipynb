# %% [raw]
# What is uninformed search?
#
# Uninformed search (also called blind search) is a category of search algorithms used in Artificial Intelligence that explore a search space without any domain-specific knowledge — that is, they have no information about the goal’s location beyond the problem definition itself.
#
# They simply use the structure of the problem (like possible states and transitions) to search for a goal, without any heuristic guidance.
#
# Uninformed search algorithms explore nodes systematically — they don’t know which paths are more promising. They just follow a predefined strategy (e.g., breadth-first, depth-first, etc.) until they find a goal.

# %% [raw]
# What are differences between informed search and uninformed search?
#
# Informed search — also known as heuristic search — is a type of search strategy in Artificial Intelligence (AI) that uses extra knowledge or heuristics about the problem domain to guide the search more efficiently toward the goal.
#
# Unlike uninformed search, which explores blindly, informed search uses estimates of how close a given state is to the goal to make smarter decisions about which path to explore next.

# %%
graph = {        #frot he DFS (Depth-First Search)
'A': ['B', 'C'], #A is the first subnode, then will go to B 
'B': ['D', 'E'], #from B it will go do D
'C': ['F'],      #from C it will go to F 
'D': [],         #after going to be D, there is no subnode, so it will go do E
'E': ['F'],      #from E it will go to F 
'F': []          #from F it will go to C, since there is no more subnode 
}

# %%
from collections import deque

def bfs(graph, start):            #visit all the neighbors of the current node, then go to the neighbors if the following node
    visited = set()
    queue = deque([start])
        
    while queue:
        vertex = queue.popleft()
        if vertex not in visited:
            print(vertex, end=" ")
            visited.add(vertex)
            queue.extend([node for node in graph[vertex] if node not in visited])

def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()
    visited.add(start)
    print(start, end=" ")
                             
    for neighbor in graph[start]:
        if neighbor not in visited:
            dfs(graph, neighbor, visited)

# %%
print("BFS:")
bfs(graph, 'A')

print("\nDFS:")
dfs(graph, 'A')
# Out:
# BFS:
# A B C D E F
# DFS:
# A B D E F C
